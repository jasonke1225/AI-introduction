# %%
import matplotlib
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../JasonKe/results/account_value_test.csv', names=['index','account_value'])
account_DDPG = df[df.index >= 1].account_value

df = pd.read_csv('../Yoyo/results/account_value_train.csv', names=['index','account_value'])
account_PPO = df[df.index >= 1].account_value

df = pd.read_csv('results/account_value_min_var.csv', names=['index','account_value'])
account_MIN_VAR = df[df.index >= 1].account_value

print(f"Trading Days:\n\tthe past {len(account_A2C)} days\n")
fig , ax = plt.subplots()
plt.plot( account_DDPG, 'r', label="DDPG")
plt.plot( account_PPO, 'b', label="PPO")
plt.plot( account_MIN_VAR, 'g', label="Min-varaince")
leg = ax.legend(loc='upper left', shadow=True) 
plt.show()
# Out:
# Trading Days:
# 	the past 731 days
